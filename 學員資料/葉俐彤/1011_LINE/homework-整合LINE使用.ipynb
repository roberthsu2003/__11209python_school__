# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 回家作業-整合LINE使用
# [整合LINE使用 講義](https://github.com/roberthsu2003/python/tree/master/line)
#
# ![image.png](attachment:image.png)
